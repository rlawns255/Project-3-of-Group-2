# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine , inspect
import psycopg2
import configparser

# %%
# parse credentials.conf for credentials
parser = configparser.ConfigParser()
parser.read("credentials.conf")
host = parser.get("postgres_config" , "host_name")
db_name = parser.get("postgres_config" , "db_name")
user = parser.get("postgres_config" , "user")
password = parser.get("postgres_config" , "password")
port = parser.get("postgres_config" , "port")

# %%
### Create engine 
        ### Create a f string and pass it to a variable
        ### create engine 
conn_string = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{db_name}'
engine = create_engine(conn_string)

# %%
# Reflect apple_tv database into a model
Base = automap_base()
Base.prepare(autoload_with=engine)

# %%
# Check out base keys
Base.classes.keys()
# Out:
# ['titles', 'credits']

# %%
#Create reference to class
titles = Base.classes.titles
credits = Base.classes.credits

# %%
# check tables

inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['titles', 'credits']

# %%
# Create session
session = Session(engine)

# %%
# Start query:
    ## I'm going to create a table that combines the title , release_year and imdb_score from titles and name and character from credits
session.query(titles.title , titles.release_year , titles.imdb_score , credits.name , credits.character)\
       .filter(titles.id == credits.title_id).all()
# Out:
# [('A Charlie Brown Christmas', 1965, 8.3, 'Peter Robbins', 'Charlie Brown (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Christopher Shea', 'Linus Van Pelt (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Tracy Stratford', 'Lucy Van Pelt (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Cathy Steinberg', 'Sally Brown (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Bill Melendez', 'Snoopy (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Chris Doran', 'Schroeder / Shermy (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Sally Dryer', 'Violet (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Karen Mendelson', 'Patty (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Geoffrey Ornstein', 'Pig-Pen (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Ann Altieri', 'Frieda (voice)'),
#  ('A Charlie Brown Christmas', 1965, 8.3, 'Bill Melendez', None),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Peter Robbins', 'Charlie Brown (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Christopher Shea', 'Linus Van Pelt (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Sally Dryer', 'Lucy Van Pelt (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Bill Melendez', 'Snoopy (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Cathy Steinberg', 'Sally Brown (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Gail DeFaria', 'Pigpen (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Glenn Mendelson', 'Schroeder / Shermy (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Ann Altieri', 'Frieda / Violet (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Lisa DeFaria', 'Patty (voice)'),
#  ("It's the Great Pumpkin, Charlie Brown", 1966, 8.2, 'Bill Melendez', None),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Todd Barbee', 'Charlie Brown (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Robin Kohn', 'Lucy van Pelt (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Stephen Shea', 'Linus van Pelt (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Hilary Momberger-Powers', 'Sally Brown (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Christopher DeFaria', "Patricia 'Peppermint Patty' Reichardt (voice)"),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Jimmy Ahrens', 'Marcie (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Bill Melendez', 'Snoopy / Woodstock (voice) (uncredited)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Robin Reed', 'Franklin (voice)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Vince Guaraldi', 'Little Birdie Singer (voice) (uncredited)'),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Peter Robbins', "Charlie Brown's screaming voice (voice) (uncredited)"),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Phil Roman', None),
#  ('A Charlie Brown Thanksgiving', 1973, 7.7, 'Bill Melendez', None),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Duncan Watson', 'Charlie Brown (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Stephen Shea', 'Linus van Pelt (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Melanie Kohn', 'Lucy van Pelt (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Greg Felton', 'Schroeder (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Lynn Mortensen', 'Sally Brown (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Linda Ercoli', 'Violet / Frieda (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Bill Melendez', 'Snoopy / Woodstock (voice)'),
#  ('Be My Valentine, Charlie Brown', 1975, 7.4, 'Phil Roman', None),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Todd Barbee', 'Charlie Brown / Schroeder (voice)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Melanie Kohn', 'Lucy van Pelt (voice)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Stephen Shea', 'Linus van Pelt (voice)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Linda Ercoli', "Patricia 'Peppermint Patty' Reichardt (voice)"),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Lynn Mortensen', 'Sally Brown / Violet / Frieda (voice)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Jimmy Ahrens', 'Marcie (voice)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Bill Melendez', 'Snoopy / Woodstock (voice) (uncredited)'),
#  ("It's the Easter Beagle, Charlie Brown", 1974, 7.5, 'Phil Roman', None),
#  ('Fraggle Rock', 1983, 7.9, 'Jerry Nelson', 'Gobo Fraggle / Marjory the Trash Heap / Pa Gorg / Uncle Gobo Fraggle / Mervin Merggle / Fishface / Parrot / Architect Doozer / Feenie Fraggle / Radio Announcers (voice)'),
#  ('Fraggle Rock', 1983, 7.9, 'Steve Whitmire', 'Wembley Fraggle / Sprocket the Dog / Mermer Merggle / Crusty Doozer / Venerable Sage Hambo / Murray the Minstrel / Flange Doozer / Sir Blunderbrain / Club Member #3 (voice)'),
#  ('Fraggle Rock', 1983, 7.9, 'Karen Prell', "Red Fraggle / Balsam the Minstrel / Wingnut Doozer / Judge Gaval Fraggle / Marly Fraggle / Gorg's Killer Souffle / Wingnut Fraggle / Fluffinella / Modem Doozer / The Beast / Baby Tree Creature (voice)"),
#  ('Fraggle Rock', 1983, 7.9, 'Dave Goelz', "Boober / Uncle Traveling Matt / Side Bottom / The World's Oldest Fraggle (voice)"),
#  ('Fraggle Rock', 1983, 7.9, 'Kathryn Mullen', 'Mokey Fraggle / Cotterpin Dozer / Crosscut Doozer / Merboo Merggle / Rock Hockey Hannah / Wimple Fraggle / The Old Gypsy Lady / Sally Spotless / Tammy Shrub / Baby Doozer / Doozer #2 (voice)'),
#  ('Fraggle Rock', 1983, 7.9, 'Gerard Parkes', 'Doc'),
#  ('Fraggle Rock', 1983, 7.9, 'Bob Stutt', 'Muppet Performer / Felix the Fearless / Wandering McMooch / Last of the Lily Creatures / The Avalanche Monster / Bigmouth Fraggle (voice)'),
#  ('Fraggle Rock', 1983, 7.9, 'Richard Hunt', 'Junior Gorg (himself) / Gunge / Mudwell the Mudbunny / Herkimer Fraggle / The Spiderfly / Gillis Fraggle / Turbo / The Genie / Purple Fragglette / Fire Chief Fraggle / Flex Doozer / Background Fraggles (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Chad Allen', 'Charlie Brown (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Kristie Baker', 'Peppermint Patty (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Melissa Guzzi', 'Lucy van Pelt (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Aron Mandelbaum', 'Schroeder (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Jeremy Miller', 'Linus van Pelt (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Jason Mendelson', 'Marcie (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Elizabeth Lyn Fraser', 'Sally Brown (voice)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Bill Melendez', 'Snoopy / Woodstock (voice) (uncredited)'),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Sam Jaimes', None),
#  ('Happy New Year, Charlie Brown', 1986, 7.2, 'Bill Melendez', None),
#  ('Out of Sight', 1998, 7.0, 'George Clooney', 'Jack Foley'),
#  ('Out of Sight', 1998, 7.0, 'Jennifer Lopez', 'Karen Sisco'),
#  ('Out of Sight', 1998, 7.0, 'Ving Rhames', 'Buddy Bragg'),
#  ('Out of Sight', 1998, 7.0, 'Don Cheadle', "Maurice 'Snoopy' Miller"),
#  ('Out of Sight', 1998, 7.0, 'Steve Zahn', 'Glenn Michaels'),
#  ('Out of Sight', 1998, 7.0, 'Dennis Farina', 'Marshall Sisco'),
#  ('Out of Sight', 1998, 7.0, 'Catherine Keener', 'Adele Delisi'),
#  ('Out of Sight', 1998, 7.0, 'Isaiah Washington', 'Kenneth'),
#  ('Out of Sight', 1998, 7.0, 'Albert Brooks', 'Richard Ripley'),
#  ('Out of Sight', 1998, 7.0, 'Luis Guzmán', "José 'Chino' Chirino"),
#  ('Out of Sight', 1998, 7.0, 'Viola Davis', 'Moselle'),
#  ('Out of Sight', 1998, 7.0, 'Jim Robinson', 'Bank Employee'),
#  ('Out of Sight', 1998, 7.0, 'Mike Malone', 'Bank Customer'),
#  ('Out of Sight', 1998, 7.0, 'Donna Frenzel', 'Bank Teller'),
#  ('Out of Sight', 1998, 7.0, 'Manny Suarez', 'Bank Cop'),
#  ('Out of Sight', 1998, 7.0, 'Keith Hudson', 'Bank Cop'),
#  ('Out of Sight', 1998, 7.0, 'Paul Soileau', 'Lulu'),
#  ('Out of Sight', 1998, 7.0, 'Scott Allen', 'Pup'),
#  ('Out of Sight', 1998, 7.0, 'Susan Hatfield', 'Parking Lot Woman'),
#  ('Out of Sight', 1998, 7.0, 'Brad Martin', 'White Boxer'),
#  ('Out of Sight', 1998, 7.0, 'James Black', 'Himey'),
#  ('Out of Sight', 1998, 7.0, 'Wendell B. Harris Jr.', 'Daniel Burdon'),
#  ('Out of Sight', 1998, 7.0, 'Chuck Castleberry', 'Library Guard'),
#  ('Out of Sight', 1998, 7.0, 'Chic Daniel', 'Shock Lock FBI Man'),
#  ('Out of Sight', 1998, 7.0, 'Keith Loneker', 'White Boy Bob'),
#  ('Out of Sight', 1998, 7.0, 'Connie Sawyer', 'Old Elevator Lady'),
#  ('Out of Sight', 1998, 7.0, 'Philip Perlman', 'Old Elevator Gent'),
#  ('Out of Sight', 1998, 7.0, 'Paul Calderon', 'Raymond Cruz'),
#  ('Out of Sight', 1998, 7.0, 'Gregory Alpert', 'Officer Grant'),
#  ('Out of Sight', 1998, 7.0, 'Mark Brown', 'Ripley Personnel'),
#  ('Out of Sight', 1998, 7.0, 'Sandra Ives', 'Ripley Receptionist'),
#  ('Out of Sight', 1998, 7.0, 'Joe Hess', 'Ripley Guard'),
#  ('Out of Sight', 1998, 7.0, 'Betsy Monroe', 'Waitress'),
#  ('Out of Sight', 1998, 7.0, 'Wayne Pére', 'Philip'),
#  ('Out of Sight', 1998, 7.0, 'Joe Chrest', 'Andy'),
#  ('Out of Sight', 1998, 7.0, 'Joe Coyle', 'Third Ad Guy'),
#  ('Out of Sight', 1998, 7.0, 'Nancy Allen', 'Midge'),
#  ('Out of Sight', 1998, 7.0, 'Michael Keaton', 'Ray Nicolette (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Samuel L. Jackson', 'Hejirah Henry (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Stephen M. Horn', 'Federal Marshal'),
#  ('Out of Sight', 1998, 7.0, 'Oscar A. Diaz', 'Airport Patron (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Jennifer Dorogi', 'Waitress (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Deborah Smith Ford', 'Airport Passenger (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Mike Gerzevitz', 'Xenon Light Guard (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Thelma Gutiérrez', 'Flight Attendant (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Wayne V. Johnson', 'Bank Manager (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Pati Lauren', 'Bank Patron (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Sherrie Peterson', 'Shopper (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Ronnie Stutes', 'Gas Station Attendant (uncredited)'),
#  ('Out of Sight', 1998, 7.0, 'Steven Soderbergh', None),
#  ('Entrapment', 1999, 6.3, 'Catherine Zeta-Jones', 'Virginia Gin Baker'),
#  ('Entrapment', 1999, 6.3, 'Sean Connery', 'Robert Mac MacDougal'),
#  ('Entrapment', 1999, 6.3, 'Will Patton', 'Hector Cruz'),
#  ('Entrapment', 1999, 6.3, 'Maury Chaykin', 'Conrad Greene'),
#  ('Entrapment', 1999, 6.3, 'Ving Rhames', 'Aaron Thibadeaux'),
#  ('Entrapment', 1999, 6.3, 'Kevin McNally', 'Haas'),
#  ('Entrapment', 1999, 6.3, "Terry O'Neill", 'Quinn'),
#  ('Entrapment', 1999, 6.3, 'Madhav Sharma', 'Security Chief'),
#  ('Entrapment', 1999, 6.3, 'David Yip', 'Chief of Police'),
#  ('Entrapment', 1999, 6.3, 'Tim Potter', 'Millennium Man'),
#  ('Entrapment', 1999, 6.3, 'Eric Meyers', 'Waverly Technician'),
#  ('Entrapment', 1999, 6.3, 'Aaron Swartz', "Cruz's Man"),
#  ('Entrapment', 1999, 6.3, 'William Marsh', 'Computer Technician'),
#  ('Entrapment', 1999, 6.3, 'Tony Xu', 'Banker'),
#  ('Entrapment', 1999, 6.3, 'Rolf Saxon', 'ICB Director'),
#  ('Entrapment', 1999, 6.3, 'Tom Clarke Hill', 'ICB Operator'),
#  ('Entrapment', 1999, 6.3, 'David Howard', 'ICB Technician'),
#  ('Entrapment', 1999, 6.3, 'Sai-Kit Yung', 'Doctor'),
#  ('Entrapment', 1999, 6.3, 'Ravin J. Ganatra', '1st Security Guard'),
#  ('Entrapment', 1999, 6.3, 'Rhydian Jai-Persad', '2nd Security Guard'),
#  ('Entrapment', 1999, 6.3, 'Hari Dhillon', '3rd Security Guard'),
#  ('Entrapment', 1999, 6.3, 'Jon Amiel', None),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Jamie E. Smith', 'Charlie Brown (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'John Christian Graas', 'Linus Van Pelt (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Marnette Patterson', 'Lucy Van Pelt / Frieda (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Mindy Ann Martin', 'Sally Brown (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Bill Melendez', 'Snoopy / Woodstock (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Phillip Lucier', 'Peppermint Patty (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Lindsay Benesh', 'Marcie / Patty (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Sean Mendelson', 'Franklin (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Deanna Tello', 'Peggy Jean / Violet (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Matthew Slowik', 'Harold Angel (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Brittany Thornton', 'Additional voices (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Jodie Sweetin', 'Sally Brown (voice)'),
#  ("It's Christmastime Again, Charlie Brown", 1992, 6.9, 'Bill Melendez', None),
#  ('The Italian Job', 2003, 7.0, 'Mark Wahlberg', 'Charlie Croker'),
#  ('The Italian Job', 2003, 7.0, 'Charlize Theron', 'Stella Bridger'),
#  ('The Italian Job', 2003, 7.0, 'Edward Norton', 'Steve'),
#  ('The Italian Job', 2003, 7.0, 'Jason Statham', 'Handsome Rob'),
#  ('The Italian Job', 2003, 7.0, 'Seth Green', 'Lyle'),
#  ('The Italian Job', 2003, 7.0, 'Yasiin Bey', 'Left Ear'),
#  ('The Italian Job', 2003, 7.0, 'Donald Sutherland', 'John Bridger'),
#  ('The Italian Job', 2003, 7.0, 'Boris Lee Krutonog', 'Yevhen'),
#  ('The Italian Job', 2003, 7.0, 'Franky G', 'Wrench'),
#  ('The Italian Job', 2003, 7.0, 'Gawtti', 'Skinny Pete'),
#  ('The Italian Job', 2003, 7.0, 'Olek Krupa', 'Mashkov'),
#  ('The Italian Job', 2003, 7.0, 'Melanie Jayne', "Skinny Pete's Girl"),
#  ('The Italian Job', 2003, 7.0, 'Kobra Devoux', "Pete's Guard"),
#  ('The Italian Job', 2003, 7.0, 'Oscar Nunez', 'Security Guard'),
#  ('The Italian Job', 2003, 7.0, 'Fausto Callegarini', 'Italian Guard'),
#  ('The Italian Job', 2003, 7.0, 'Stefano Petronelli', 'Garbageman'),
#  ('The Italian Job', 2003, 7.0, 'Fabio Scarpa', 'Garbageman'),
#  ('The Italian Job', 2003, 7.0, 'Cristiano Bonora', 'Garbageman'),
#  ('The Italian Job', 2003, 7.0, 'Tiberio Greco', 'Garbageman'),
#  ('The Italian Job', 2003, 7.0, 'Mary Portser', "Stella's Receptionist"),
#  ('The Italian Job', 2003, 7.0, 'Gregory Scott Cummins', 'Ukranian'),
#  ('The Italian Job', 2003, 7.0, 'Scott Adsit', 'Actor Rehearsing In Car'),
#  ('The Italian Job', 2003, 7.0, 'Kelly Brook', "Lyle's Girlfriend"),
#  ('The Italian Job', 2003, 7.0, 'Erik Walker', 'Bully'),
#  ('The Italian Job', 2003, 7.0, 'Jimmy Shubert', 'First Detective'),
#  ('The Italian Job', 2003, 7.0, 'Tammi Cubilette', 'Second Detective'),
#  ('The Italian Job', 2003, 7.0, 'Simon Rhee', 'Armored Truck Guard'),
#  ('The Italian Job', 2003, 7.0, 'Joel Homan', 'Young Charlie'),
#  ('The Italian Job', 2003, 7.0, 'Julie Costello', 'Becky'),
#  ('The Italian Job', 2003, 7.0, 'Marty Ryan', 'ATSAC Supervisor'),
#  ('The Italian Job', 2003, 7.0, 'Aaron Speiser', 'Danielson'),
#  ('The Italian Job', 2003, 7.0, 'Thomas Alexander', 'Vance'),
#  ('The Italian Job', 2003, 7.0, 'Martin Morales', 'Valet'),
#  ('The Italian Job', 2003, 7.0, 'Frank Nyi', 'ATSAC Employee'),
#  ('The Italian Job', 2003, 7.0, 'Merritt Yohnka', 'Gold Truck Driver'),
#  ('The Italian Job', 2003, 7.0, 'Ryan B. Adams', 'Metro Conductor'),
#  ('The Italian Job', 2003, 7.0, 'John Alden', 'Motorcycle Guard'),
#  ('The Italian Job', 2003, 7.0, "Gloria O'Brien", "Handsome Rob's Policewoman"),
#  ('The Italian Job', 2003, 7.0, 'F. Gary Gray', None),
#  ('Matchstick Men', 2003, 7.3, 'Nicolas Cage', 'Roy Waller'),
#  ('Matchstick Men', 2003, 7.3, 'Sam Rockwell', 'Frank Mercer'),
#  ('Matchstick Men', 2003, 7.3, 'Alison Lohman', 'Angela'),
#  ('Matchstick Men', 2003, 7.3, 'Bruce Altman', 'Dr. Klein'),
#  ('Matchstick Men', 2003, 7.3, 'Bruce McGill', 'Chuck Frechette'),
#  ('Matchstick Men', 2003, 7.3, "Jenny O'Hara", 'Mrs. Schaffer'),
#  ('Matchstick Men', 2003, 7.3, 'Steve Eastin', 'Mr. Schaffer'),
#  ('Matchstick Men', 2003, 7.3, 'Beth Grant', 'Laundry Lady'),
#  ('Matchstick Men', 2003, 7.3, 'Sheila Kelley', 'Kathy'),
#  ('Matchstick Men', 2003, 7.3, 'Fran Kranz', 'Slacker Boyfriend'),
#  ('Matchstick Men', 2003, 7.3, 'Tim Kelleher', 'Bishop'),
#  ('Matchstick Men', 2003, 7.3, 'Nigel Gibbs', 'Holt'),
#  ('Matchstick Men', 2003, 7.3, 'Bill Saito', 'Pharmacist #1'),
#  ('Matchstick Men', 2003, 7.3, 'Tim Maculan', 'Pharmacist #2'),
#  ('Matchstick Men', 2003, 7.3, 'Stoney Westmoreland', 'Man in Line'),
#  ('Matchstick Men', 2003, 7.3, 'Lynn Ann Leveridge', 'Bank Clerk'),
#  ('Matchstick Men', 2003, 7.3, 'Giannina Facio', 'Bank Teller'),
#  ('Matchstick Men', 2003, 7.3, 'Sonya Eddy', 'Parking Garage Cashier'),
#  ('Matchstick Men', 2003, 7.3, 'Michael Clossin', 'Long Winded Parking Booth Driver'),
#  ('Matchstick Men', 2003, 7.3, 'Kim Cassidy', 'Stripper'),
#  ('Matchstick Men', 2003, 7.3, 'Paul Hubbard', 'Store Clerk'),
#  ('Matchstick Men', 2003, 7.3, 'Monnae Michaell', 'Carpet Store Manager'),
#  ('Matchstick Men', 2003, 7.3, 'Dennis Anderson', 'Cashier'),
#  ('Matchstick Men', 2003, 7.3, 'Marco Kyris', 'Pizza Boy'),
#  ('Matchstick Men', 2003, 7.3, 'Jerry Hauck', 'Taxi Cab Driver'),
#  ('Matchstick Men', 2003, 7.3, 'Jim Zulevic', 'Bartender'),
#  ('Matchstick Men', 2003, 7.3, 'Ramsey Malouky', 'Hospital Intern'),
#  ('Matchstick Men', 2003, 7.3, 'Andi Sherrill', 'Pharmacy Cashier'),
#  ('Matchstick Men', 2003, 7.3, 'Kate Steele', 'Strip Club Waitress'),
#  ('Matchstick Men', 2003, 7.3, 'Adam Clark', 'Strip Club Bouncer'),
#  ('Matchstick Men', 2003, 7.3, 'Daniel Villarreal', 'Car Wash Employee'),
#  ('Matchstick Men', 2003, 7.3, 'Marco Assante', 'Valet Parker'),
#  ('Matchstick Men', 2003, 7.3, 'Melora Walters', 'Heather (uncredited)'),
#  ('Matchstick Men', 2003, 7.3, 'Larry Vigus', 'Pharmacy Customer (uncredited)'),
#  ('Matchstick Men', 2003, 7.3, 'Ridley Scott', None),
#  ('Long Way Round', 2004, 8.6, 'Ewan McGregor', 'Himself'),
#  ('Long Way Round', 2004, 8.6, 'Charley Boorman', 'Himself'),
#  ('Long Way Round', 2004, 8.6, 'Russ Malkin', None),
#  ('Long Way Round', 2004, 8.6, 'David Alexanian', None),
#  ('Long Way Down', 2007, 8.6, 'Charley Boorman', 'Himself'),
#  ('Long Way Down', 2007, 8.6, 'Ewan McGregor', 'Himself'),
#  ('Long Way Down', 2007, 8.6, 'David Alexanian', 'Self'),
#  ('Long Way Down', 2007, 8.6, 'Russ Malkin', 'Self'),
#  ('Long Way Down', 2007, 8.6, 'Jimmy Simak', 'Self'),
#  ('Long Way Down', 2007, 8.6, 'David Alexanian', None),
#  ('Long Way Down', 2007, 8.6, 'Russ Malkin', None),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Jimmy Bennett', 'Rerun Van Pelt (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Adam Taylor Gordon', 'Charlie Brown (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Ashley Rose Orr', 'Lucy Van Pelt (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Corey Padnos', 'Linus Van Pelt (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Hannah Leigh', 'Sally Brown (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Nick Price', 'Schroeder (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Jake Miner', 'Pig Pen / Franklin (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Kaitlyn Maggio', 'Little Pigtailed Girl / Violet / Patty / Frieda (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Bill Melendez', 'Snoopy / Spike (voice)'),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Larry Leichliter', None),
#  ('I Want a Dog for Christmas, Charlie Brown', 2003, 7.0, 'Bill Melendez', None),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Wesley Singerman', 'Charlie Brown (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Serena Berman', 'Lucy Van Pelt (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Corey Padnos', 'Linus van Pelt (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Megan Taylor Harvey', 'Sally Brown (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Christopher Johnson', 'Schroeder (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Timmy Deters', 'Rerun Van Pelt (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Lauren Schaffel', 'Jezebel / Lydia (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Bill Melendez', 'Snoopy / Woodstock (voice)'),
#  ("Charlie Brown's Christmas Tales", 2002, 7.0, 'Larry Leichliter', None),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Wesley Singerman', 'Charlie Brown (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Lauren Schaffel', 'Lucy Van Pelt (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Corey Padnos', 'Linus Van Pelt (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Emily Lalande', 'Peppermint Patty (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Jessica D. Stone', 'Marcie (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Nicolette Little', 'Sally (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Christopher Johnson', 'Schroeder (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Bill Melendez', 'Snoopy (voice)'),
#  ('A Charlie Brown Valentine', 2002, 7.1, 'Bill Melendez', None),
#  ('The Five-Year Engagement', 2012, 6.2, 'Jason Segel', 'Tom Solomon'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Emily Blunt', 'Violet Barnes'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Rhys Ifans', 'Winton Childs'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Chris Pratt', 'Alex Eilhauer'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Alison Brie', 'Suzie Barnes'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Jacki Weaver', 'Sylvia Dickerson-Barnes'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Jim Piddock', 'George Barnes'),
#  ('The Five-Year Engagement', 2012, 6.2, 'David Paymer', 'Pete Solomon'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Mimi Kennedy', 'Carol Solomon'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Mindy Kaling', 'Vaneetha'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Kevin Hart', 'Doug'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Brian Posehn', 'Tarquin'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Chris Parnell', 'Bill'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Lauren Weedman', 'Chef Sally'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Tracee Chimo', 'Margaret'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Adam Campbell', 'Gideon'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Dakota Johnson', 'Audrey'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Randall Park', 'Ming'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Jane Carr', 'Grandma Katherine'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Clement von Franckenstein', 'Grandpa Baba'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Michael Ensign', 'Grandpa Harold'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Madge Levinson', 'Grandma Leonora'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Laurie Brown', 'Professor Walch'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Chris Newman', 'Used Car Lot Guy'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Murray Miller', 'SF Wedding Barn Manager'),
#  ('Visible: Out On Television', 2020, 8.3, 'Sara Ramirez', 'Self'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Eileen Grubba', 'Botanical Garden Manager'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Mark Rademacher', 'Priest'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Kevin Yon', 'Rabbi'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Heather Mathieson', 'Female Justice of the Peace'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Kumail Nanjiani', 'Pakistani Chef'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Gina Ragnone', 'Ashley'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Stephanie Faracy', 'Florist'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Aaron Lustig', 'Michigan Rabbi'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Tim Heidecker', 'Negotiating Chef'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Molly Shannon', 'Onion Chef'),
#  ('The Five-Year Engagement', 2012, 6.2, 'AnnaCorey', 'Jill Wedding Attendee (uncredited)'),
#  ('The Five-Year Engagement', 2012, 6.2, 'Nicholas Stoller', None),
#  ('Ted Lasso', 2020, 8.8, 'Jason Sudeikis', 'Ted Lasso'),
#  ('Ted Lasso', 2020, 8.8, 'Hannah Waddingham', 'Rebecca Welton'),
#  ('Ted Lasso', 2020, 8.8, 'Juno Temple', 'Keeley Jones'),
#  ('Ted Lasso', 2020, 8.8, 'Jeremy Swift', 'Leslie Higgins'),
#  ('Ted Lasso', 2020, 8.8, 'Phil Dunster', 'Jamie Tartt'),
#  ('Ted Lasso', 2020, 8.8, 'Brett Goldstein', 'Roy Kent'),
#  ('Ted Lasso', 2020, 8.8, 'Brendan Hunt', 'Coach Beard'),
#  ('Ted Lasso', 2020, 8.8, 'Nick Mohammed', 'Nathan Shelley'),
#  ('Servant', 2019, 7.5, 'Lauren Ambrose', 'Dorothy Turner'),
#  ('Servant', 2019, 7.5, 'Toby Kebbell', 'Sean Turner'),
#  ('Servant', 2019, 7.5, 'Rupert Grint', 'Julian Pearce'),
#  ('Servant', 2019, 7.5, 'Nell Tiger Free', 'Leanne Grayson'),
#  ('For All Mankind', 2019, 8.0, 'Joel Kinnaman', 'Ed Baldwin'),
#  ('For All Mankind', 2019, 8.0, 'Shantel VanSanten', 'Karen Baldwin'),
#  ('For All Mankind', 2019, 8.0, 'Jodi Balfour', 'Ellen Wilson'),
#  ('For All Mankind', 2019, 8.0, 'Krys Marshall', 'Danielle Poole'),
#  ('For All Mankind', 2019, 8.0, 'Edi Gathegi', 'Dev Ayesa'),
#  ('For All Mankind', 2019, 8.0, 'Cynthy Wu', 'Kelly Baldwin'),
#  ('For All Mankind', 2019, 8.0, 'Casey Johnson', 'Danny Stevens'),
#  ('For All Mankind', 2019, 8.0, 'Coral Peña', 'Aleida Rosales'),
#  ('For All Mankind', 2019, 8.0, 'Wrenn Schmidt', 'Margo Madison'),
#  ('Mythic Quest', 2020, 7.8, 'Rob McElhenney', 'Ian Grimm'),
#  ('Mythic Quest', 2020, 7.8, 'Charlotte Nicdao', 'Poppy Li'),
#  ('Mythic Quest', 2020, 7.8, 'David Hornsby', 'David Brittlesbee'),
#  ('Mythic Quest', 2020, 7.8, 'Danny Pudi', 'Brad Bakshi'),
#  ('Mythic Quest', 2020, 7.8, 'Ashly Burch', 'Rachel'),
#  ('Mythic Quest', 2020, 7.8, 'Imani Hakim', 'Dana'),
#  ('Mythic Quest', 2020, 7.8, 'Jessie Ennis', 'Jo'),
#  ('Mythic Quest', 2020, 7.8, 'Naomi Ekperigin', 'Carol'),
#  ('Truth Be Told', 2019, 7.1, 'Octavia Spencer', 'Poppy Scoville'),
#  ('Truth Be Told', 2019, 7.1, 'Mekhi Phifer', 'Markus Killebrew'),
#  ('Truth Be Told', 2019, 7.1, 'Ron Cephas Jones', "Leander 'Shreve' Scoville"),
#  ('Truth Be Told', 2019, 7.1, 'Tracie Thoms', 'Desiree Scoville'),
#  ('Truth Be Told', 2019, 7.1, 'Haneefah Wood', 'Cydie Scoville'),
#  ('Truth Be Told', 2019, 7.1, 'Gabrielle Union', 'Eva Pierre'),
#  ('The Morning Show', 2019, 8.3, 'Jennifer Aniston', 'Alex Levy'),
#  ('The Morning Show', 2019, 8.3, 'Reese Witherspoon', 'Bradley Jackson'),
#  ('The Morning Show', 2019, 8.3, 'Billy Crudup', 'Cory Ellison'),
#  ('The Morning Show', 2019, 8.3, 'Mark Duplass', "Charlie 'Chip' Black"),
#  ('The Morning Show', 2019, 8.3, 'Greta Lee', 'Stella Bak'),
#  ('The Morning Show', 2019, 8.3, 'Nestor Carbonell', 'Yanko Flores'),
#  ('The Morning Show', 2019, 8.3, 'Julianna Margulies', 'Laura Peterson'),
#  ('The Morning Show', 2019, 8.3, 'Karen Pittman', 'Mia Jordan'),
#  ('The Morning Show', 2019, 8.3, 'Desean Terry', 'Daniel Henderson'),
#  ('The Morning Show', 2019, 8.3, "Ruairí O'Connor", 'Ty Fitzgerald'),
#  ('See', 2019, 7.6, 'Jason Momoa', 'Baba Voss'),
#  ('See', 2019, 7.6, 'Sylvia Hoeks', 'Queen Sibeth Kane'),
#  ('See', 2019, 7.6, 'Hera Hilmar', 'Maghra'),
#  ('See', 2019, 7.6, 'Christian Camargo', 'Tamacti Jun'),
#  ('See', 2019, 7.6, 'Archie Madekwe', 'Kofun'),
#  ('See', 2019, 7.6, 'Nesta Cooper', 'Haniwa'),
#  ('See', 2019, 7.6, 'Eden Epstein', 'Wren'),
#  ('See', 2019, 7.6, 'Olivia Cheng', 'Charlotte'),
#  ('See', 2019, 7.6, 'Tom Mison', 'Lord Harlan'),
#  ('See', 2019, 7.6, 'Michael Raymond-James', 'Ranger'),
#  ('See', 2019, 7.6, 'David Hewlett', 'Tormada'),
#  ('The Banker', 2020, 7.3, 'Anthony Mackie', 'Bernard Garrett'),
#  ('The Banker', 2020, 7.3, 'Samuel L. Jackson', 'Joe Morris'),
#  ('The Banker', 2020, 7.3, 'Nicholas Hoult', 'Matt Steiner'),
#  ('The Banker', 2020, 7.3, 'Nia Long', 'Eunice Garrett'),
#  ('The Banker', 2020, 7.3, 'Jessie T. Usher', 'Tony Jackson'),
#  ('The Banker', 2020, 7.3, 'Colm Meaney', 'Patrick Barker'),
#  ('The Banker', 2020, 7.3, 'Paul Ben-Victor', 'Donald Silverthorne'),
#  ('The Banker', 2020, 7.3, 'James DuMont', 'Senator McClellan'),
#  ('The Banker', 2020, 7.3, 'Taylor Black', 'Susie'),
#  ('The Banker', 2020, 7.3, 'Gregory Alan Williams', 'Britton Garrett'),
#  ('The Banker', 2020, 7.3, 'Bill Kelly', 'Charles Renault'),
#  ('The Banker', 2020, 7.3, 'Jaylon Gordon', 'Bernard Jr. (11 Years Old)'),
#  ('The Banker', 2020, 7.3, 'Michael Harney', 'Melvin Belli'),
#  ('The Banker', 2020, 7.3, 'David Maldonado', 'Bank Examiner'),
#  ('The Banker', 2020, 7.3, 'Craig Welzbacher', 'Deputy Comptroller Dunn'),
#  ('The Banker', 2020, 7.3, 'Chris Gann', '2nd FBI Man'),
#  ('The Banker', 2020, 7.3, 'Daniel Johnson', 'Minister (uncredited)'),
#  ('The Banker', 2020, 7.3, 'George Nolfi', None),
#  ('Greyhound', 2020, 7.0, 'Tom Hanks', 'Commander Krause'),
#  ('Greyhound', 2020, 7.0, 'Stephen Graham', 'Charlie Cole'),
#  ('Greyhound', 2020, 7.0, 'Rob Morgan', 'Cleveland'),
#  ('Greyhound', 2020, 7.0, 'Josh Wiggins', 'Talker #1'),
#  ('Greyhound', 2020, 7.0, 'Tom Brittney', 'Lt. Watson'),
#  ('Greyhound', 2020, 7.0, 'Elisabeth Shue', 'Evelyn'),
#  ('Greyhound', 2020, 7.0, 'Will Pullen', 'Talker #3'),
#  ('Greyhound', 2020, 7.0, 'Manuel Garcia-Rulfo', 'Lopez'),
#  ('Greyhound', 2020, 7.0, 'Karl Glusman', 'Eppstein'),
#  ('Greyhound', 2020, 7.0, 'Chet Hanks', 'Bushnell'),
#  ('Greyhound', 2020, 7.0, 'Jimi Stanton', 'Lt. Harbutt'),
#  ('Greyhound', 2020, 7.0, 'Matt Helm', 'Lt. Nystrom'),
#  ('Greyhound', 2020, 7.0, 'Devin Druid', 'Wallace'),
#  ('Greyhound', 2020, 7.0, 'Craig Tate', 'Pitts'),
#  ('Greyhound', 2020, 7.0, 'Travis Quentin', 'Ipsen'),
#  ('Greyhound', 2020, 7.0, 'Jeff Burkes', 'Shannon'),
#  ('Greyhound', 2020, 7.0, 'Matthew Zuk', 'Flusser'),
#  ('Greyhound', 2020, 7.0, 'Joseph Poliquin', 'Lee Helmsman #1'),
#  ('Greyhound', 2020, 7.0, 'Casey Bond', 'Helmsman #1'),
#  ('Greyhound', 2020, 7.0, 'Michael Benz', 'Carling'),
#  ('Greyhound', 2020, 7.0, 'Grayson Russell', 'Signalman #1'),
#  ('Greyhound', 2020, 7.0, 'Ian James Corlett', 'Dicky'),
#  ('Greyhound', 2020, 7.0, 'Maximilian Osinski', 'Eagle'),
#  ('Greyhound', 2020, 7.0, 'Dominic Keating', 'Harry'),
#  ('Greyhound', 2020, 7.0, 'Dave Davis', "Boatswain's Mate #1"),
#  ('Greyhound', 2020, 7.0, 'Parker Wierling', 'Messenger #1'),
#  ('Greyhound', 2020, 7.0, 'Ian Pala', 'Radarman'),
#  ('Greyhound', 2020, 7.0, 'Travis Przybylski', 'Dawson'),
#  ('Greyhound', 2020, 7.0, 'Cade Burk', 'Starboard Lookout'),
#  ('Greyhound', 2020, 7.0, 'Jesse Gallegos', 'Signalman #2'),
#  ('Greyhound', 2020, 7.0, 'Alex Kramer', 'Talker #2'),
#  ('Greyhound', 2020, 7.0, 'Lee Norris', 'Messenger #2'),
#  ('Greyhound', 2020, 7.0, 'Adam Aalderks', 'Helmsman #2'),
#  ('Greyhound', 2020, 7.0, 'Keon Motakhaveri', 'Lee Helmsman #2'),
#  ('Greyhound', 2020, 7.0, 'Jake Ventimiglia', 'Fippler'),
#  ('Greyhound', 2020, 7.0, 'Michael Carollo', 'Forward Lookout'),
#  ('Greyhound', 2020, 7.0, 'Caleb J. Thaggard', 'Port Lookout'),
#  ('Greyhound', 2020, 7.0, 'John Frederick', 'Chief Quartermaster Frederick'),
#  ('Greyhound', 2020, 7.0, 'Jeff Adler', 'Rudel'),
#  ('Greyhound', 2020, 7.0, 'Brandon Holubar', 'Bridge Lookout #1'),
#  ('Greyhound', 2020, 7.0, 'Joel Newsom', 'Bridge Lookout #2'),
#  ('Greyhound', 2020, 7.0, 'Thomas Kretschmann', 'Grey Wolf (voice)'),
#  ('Greyhound', 2020, 7.0, 'David Maldonado', 'Dr. Temme'),
#  ('Greyhound', 2020, 7.0, 'Jeremy Madden', 'Farnsworth'),
#  ('Greyhound', 2020, 7.0, 'Jon Donahue', 'Al'),
#  ('Greyhound', 2020, 7.0, 'Aaron Schneider', None),
#  ('Tehran', 2020, 7.6, 'Niv Sultan', 'Tamar Rabinyan'),
#  ('Tehran', 2020, 7.6, 'Shaun Toub', 'Faraz Kamali'),
#  ('Tehran', 2020, 7.6, 'Shervin Alenabi', 'Milad'),
#  ('Tehran', 2020, 7.6, 'Glenn Close', 'Marjan Montazeri'),
#  ('Tehran', 2020, 7.6, 'Darius Homayoun', 'Peyman Mohammadi'),
#  ('Little America', 2020, 7.6, 'Elisa Schlott', 'Marie Kastner'),
#  ('Little America', 2020, 7.6, 'Reomy D. Mpeho', 'George Washington'),
#  ('Little America', 2020, 7.6, 'Franziska Brandmeier', 'Erika Strumm'),
#  ('Little America', 2020, 7.6, 'Anna Schudt', 'Anneliese Strumm'),
#  ('Little America', 2020, 7.6, 'Dietmar Bär', 'Friedrich Strumm'),
#  ('Little America', 2020, 7.6, 'Julia Koschitz', 'Amy McCoy'),
#  ('Little America', 2020, 7.6, 'Jonas Nay', 'Siegfried Strumm'),
#  ('Little America', 2020, 7.6, 'Jared Lorenzo', 'Moses Shepard'),
#  ('Little America', 2020, 7.6, 'Philippe Brenninkmeyer', 'Colonel Jim McCoy'),
#  ('Little America', 2020, 7.6, 'Winnie Böwe', 'Luise Kastner'),
#  ('Little America', 2020, 7.6, 'Aljoscha Stadelmann', None),
#  ('Little America', 2020, 7.6, 'Paul Sundheim', None),
#  ('Little America', 2020, 7.6, 'Samuel Finzi', None),
#  ('Little America', 2020, 7.6, 'Artjom Gilz', 'Bill Meadow'),
#  ('Little America', 2020, 7.6, 'Tim Kalkhof', 'Hoskins'),
#  ('Little America', 2020, 7.6, 'Kelvin Kilonzo', None),
#  ('Little America', 2020, 7.6, 'Piet Fuchs', 'Pfarrer Schäfer'),
#  ('Little America', 2020, 7.6, 'Nina Gummich', None),
#  ('Little America', 2020, 7.6, 'Godehard Giese', None),
#  ('Little America', 2020, 7.6, 'Dror Zahavi', None),
#  ('Trying', 2020, 7.9, 'Rafe Spall', 'Jason'),
#  ('Trying', 2020, 7.9, 'Esther Smith', 'Nikki'),
#  ('Trying', 2020, 7.9, 'Imelda Staunton', 'Penny'),
#  ('Trying', 2020, 7.9, 'Ophelia Lovibond', 'Erica'),
#  ('Trying', 2020, 7.9, 'Oliver Chris', 'Freddy'),
#  ('Dickinson', 2019, 7.6, 'Hailee Steinfeld', 'Emily Dickinson'),
#  ('Dickinson', 2019, 7.6, 'Toby Huss', 'Edward Dickinson'),
#  ('Dickinson', 2019, 7.6, 'Adrian Enscoe', 'Austin Dickinson'),
#  ('Dickinson', 2019, 7.6, 'Anna Baryshnikov', "Lavinia 'Vinnie' Dickinson"),
#  ('Dickinson', 2019, 7.6, 'Ella Hunt', 'Sue Gilbert'),
#  ('Dickinson', 2019, 7.6, 'Amanda Warren', 'Betty'),
#  ('Dickinson', 2019, 7.6, 'Chinaza Uche', 'Henry'),
#  ('Dickinson', 2019, 7.6, 'Jane Krakowski', 'Mrs. Dickinson'),
#  ('Defending Jacob', 2020, 7.8, 'Chris Evans', 'Andy Barber'),
#  ('Defending Jacob', 2020, 7.8, 'Michelle Dockery', 'Laurie Barber'),
#  ('Defending Jacob', 2020, 7.8, 'Jaeden Martell', 'Jacob Barber'),
#  ('Defending Jacob', 2020, 7.8, 'Cherry Jones', 'Joanna Klein'),
#  ('Defending Jacob', 2020, 7.8, 'Jordan Alexa Davis', 'Sarah Grohl'),
#  ('Defending Jacob', 2020, 7.8, 'Pablo Schreiber', 'Neal Logiudice'),
#  ('Defending Jacob', 2020, 7.8, 'Betty Gabriel', 'Pam Duffy'),
#  ('Defending Jacob', 2020, 7.8, 'Sakina Jaffrey', 'Lynn Canavan'),
#  ('Defending Jacob', 2020, 7.8, 'Ben Taylor', 'Derek Yoo'),
#  ('Defending Jacob', 2020, 7.8, 'Daniel Henshall', 'Leonard Patz'),
#  ('Central Park', 2020, 6.9, 'Josh Gad', 'Birdie (voice)'),
#  ('Central Park', 2020, 6.9, 'Leslie Odom Jr.', 'Owen (voice)'),
#  ('Central Park', 2020, 6.9, 'Tituss Burgess', 'Cole (voice)'),
#  ('Central Park', 2020, 6.9, 'Daveed Diggs', 'Helen (voice)'),
#  ('Central Park', 2020, 6.9, 'Kathryn Hahn', 'Paige (voice)'),
#  ('Central Park', 2020, 6.9, 'Stanley Tucci', 'Bitsy (voice)'),
#  ('Home', 2020, 7.5, 'Corey Reeser', None),
#  ('Home', 2020, 7.5, 'Matt Tynauer', None),
#  ('Home Before Dark', 2020, 7.5, 'Brooklynn Prince', 'Hilde Lisko'),
#  ('Home Before Dark', 2020, 7.5, 'Jim Sturgess', 'Matt Lisko'),
#  ('Home Before Dark', 2020, 7.5, 'Abby Miller', 'Bridget Jensen'),
#  ('Home Before Dark', 2020, 7.5, 'Kylie Rogers', 'Izzy Lisko'),
#  ('Home Before Dark', 2020, 7.5, 'Michael Weston', 'Lt. Frank Briggs, Jr.'),
#  ('Home Before Dark', 2020, 7.5, 'Aziza Scott', 'Deputy Mackenzie ‘Trip’ Johnson III'),
#  ('Home Before Dark', 2020, 7.5, 'Joelle Carter', 'Principal Kim Collins'),
#  ('Home Before Dark', 2020, 7.5, 'Louis Herthum', 'Sheriff Frank Briggs, Sr.'),
#  ('Home Before Dark', 2020, 7.5, 'Adrian Hough', 'Mayor Jack Fife'),
#  ('Home Before Dark', 2020, 7.5, 'Jibrail Nantambu', 'Donny Davis'),
#  ('Home Before Dark', 2020, 7.5, 'Deric McCabe', 'Wesley ‘Spoon’ Witherspoon'),
#  ('Ghostwriter', 2019, 5.7, 'Princess K. Mapp', 'Nia'),
#  ('Ghostwriter', 2019, 5.7, 'Nour Assaf', 'Samir'),
#  ('Ghostwriter', 2019, 5.7, 'Daire McLeod', 'Charlie'),
#  ('Fireball: Visitors from Darker Worlds', 2020, 7.0, 'Werner Herzog', 'Self - Narrator'),
#  ('Fireball: Visitors from Darker Worlds', 2020, 7.0, 'Clive Oppenheimer', 'Self'),
#  ('Fireball: Visitors from Darker Worlds', 2020, 7.0, 'Clive Oppenheimer', None),
#  ('Fireball: Visitors from Darker Worlds', 2020, 7.0, 'Werner Herzog', None),
#  ('Wolfwalkers', 2020, 8.0, 'Honor Kneafsey', 'Robyn Goodfellowe (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Eva Whittaker', 'Mebh MacTíre (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Sean Bean', 'Bill Goodfellowe (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Simon McBurney', 'Lord Protector Cromwell (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Tommy Tiernan', 'Sean Óg (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Jon Kenny', 'Stringy Woodcutter (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'John Morton', 'Stumpy Woodcutter (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Maria Doyle Kennedy', 'Moll MacTíre (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Oliver McGrath', 'Padraig (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Niamh Moyles', 'Fishmonger (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Nora Twomey', 'Bridget (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Paul Young', 'Sheep Farmer (voice)'),
#  ('Wolfwalkers', 2020, 8.0, 'Lana Ropion', None),
#  ('Wolfwalkers', 2020, 8.0, 'Tomm Moore', None),
#  ('Wolfwalkers', 2020, 8.0, 'Ross Stewart', None),
#  ('Beastie Boys Story', 2020, 7.7, 'Michael Diamond', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'Adam Horovitz', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'Adam Yauch', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Ben Stiller', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'Steve Buscemi', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'David Cross', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'Michael Kenneth Williams', 'Self'),
#  ('Beastie Boys Story', 2020, 7.7, 'Afrika Bambaataa', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'John Berry', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Kurtis Blow', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Dick Clark', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Don Cornelius', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Adam Curry', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Tenzin Gyatso', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Matt Dike', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Karen Duffy', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'E.Z. Mike', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'King Gizmo', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Luscious Jackson', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Spike Jonze', 'Self (voice)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Kurt Loder', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Madonna', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Money Mark', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Joan Rivers', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Rick Rubin', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Kate Schellenbach', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Russell Simmons', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Michael Stipe', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Brian Williams', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'E.A. Rockwell', 'Self (archive footage)'),
#  ('Beastie Boys Story', 2020, 7.7, 'Spike Jonze', None),
#  ('Long Way Up', 2020, 8.2, 'Ewan McGregor', 'Self'),
#  ('Long Way Up', 2020, 8.2, 'Charley Boorman', 'Self'),
#  ('Long Way Up', 2020, 8.2, 'Russ Malkin', 'Self'),
#  ('Long Way Up', 2020, 8.2, 'David Alexanian', 'Self'),
#  ('Long Way Up', 2020, 8.2, 'Claudio von Planta', 'Self'),
#  ('On the Rocks', 2020, 6.4, 'Rashida Jones', 'Laura'),
#  ('On the Rocks', 2020, 6.4, 'Bill Murray', 'Felix'),
#  ('On the Rocks', 2020, 6.4, 'Marlon Wayans', 'Dean'),
#  ('On the Rocks', 2020, 6.4, 'Jessica Henwick', 'Fiona'),
#  ('On the Rocks', 2020, 6.4, 'Jenny Slate', 'Vanessa'),
#  ('On the Rocks', 2020, 6.4, 'Liyanna Muscat', 'Maya'),
#  ('On the Rocks', 2020, 6.4, 'Alexandra  Mary Reimer', 'Theo'),
#  ('On the Rocks', 2020, 6.4, 'Anna Reimer', 'Theo'),
#  ('On the Rocks', 2020, 6.4, 'Barbara Bain', 'Gran'),
#  ('On the Rocks', 2020, 6.4, 'Juliana Canfield', 'Amanda'),
#  ('On the Rocks', 2020, 6.4, 'Alva Chinn', 'Diane'),
#  ('On the Rocks', 2020, 6.4, 'Mike Keller', "Officer O'Callaghan"),
#  ('On the Rocks', 2020, 6.4, 'Musto Pelinkovicci', 'Musto'),
#  ('On the Rocks', 2020, 6.4, 'Zora Casebere', 'Babysitter 1'),
#  ('On the Rocks', 2020, 6.4, 'Melissa Errico', 'Music Teacher'),
#  ('On the Rocks', 2020, 6.4, 'Zoe Bullock', 'Jenna'),
#  ('On the Rocks', 2020, 6.4, 'Chase Sui Wonders', 'Chase'),
#  ('On the Rocks', 2020, 6.4, 'Elizabeth Guindi', 'Carla'),
#  ('On the Rocks', 2020, 6.4, 'Jules Willcox', 'Mom'),
#  ('On the Rocks', 2020, 6.4, 'Ximena Lamadrid', 'Mandy'),
#  ('On the Rocks', 2020, 6.4, 'Kelly Lynch', 'Blonde'),
#  ('On the Rocks', 2020, 6.4, 'Earl Rose', 'Piano Player'),
#  ('On the Rocks', 2020, 6.4, 'Catherine G. Blair', 'Cocktail Party Guest 1'),
#  ('On the Rocks', 2020, 6.4, 'Anne Goldrach', 'Cocktail Party Guest 2'),
#  ('On the Rocks', 2020, 6.4, 'Waltrudis Buck', 'Lady 1'),
#  ('On the Rocks', 2020, 6.4, 'Nancy Ozelli', 'Lady 2'),
#  ('On the Rocks', 2020, 6.4, 'Chris Cenatiempo', 'Police Officer 2'),
#  ('On the Rocks', 2020, 6.4, 'Cliff Samara', 'Security Attendant'),
#  ('On the Rocks', 2020, 6.4, 'Natia Dune', 'Waitress'),
#  ('On the Rocks', 2020, 6.4, 'Nadia Dajani', 'Kelly'),
#  ('On the Rocks', 2020, 6.4, 'Spice Greene', 'Host'),
#  ('On the Rocks', 2020, 6.4, 'Grayson Eddey', 'Milo'),
#  ('On the Rocks', 2020, 6.4, "Charlotte D'Alessio", 'Model Mom'),
#  ('On the Rocks', 2020, 6.4, 'Kim Hill', 'Mom at School'),
#  ('On the Rocks', 2020, 6.4, 'Evangeline Young', 'Miss Mindy'),
#  ('On the Rocks', 2020, 6.4, 'John Tropea', 'Guitar Player'),
#  ('On the Rocks', 2020, 6.4, 'Sofia Coppola', None),
#  ('Boys State', 2020, 7.6, 'Ben Feinstein', 'Self'),
#  ('Boys State', 2020, 7.6, 'Steven Garza', 'Self'),
#  ('Boys State', 2020, 7.6, 'Robert MacDougall', 'Self'),
#  ('Boys State', 2020, 7.6, 'René Otero', 'Self'),
#  ('Boys State', 2020, 7.6, 'Eddy Proietti Conti', 'Self'),
#  ('Boys State', 2020, 7.6, 'Jesse Moss', None),
#  ('Boys State', 2020, 7.6, 'Amanda McBaine', None),
#  ('Tiny World', 2020, 8.9, 'Paul Rudd', 'Narrator'),
#  ("Oprah's Book Club", 2019, 4.7, 'Oprah Winfrey', 'Self - Host'),
#  ('Visible: Out On Television', 2020, 8.3, 'Janet Mock', 'Narrator (voice)'),
#  ('Visible: Out On Television', 2020, 8.3, 'Margaret Cho', 'Narrator (voice)'),
#  ('Visible: Out On Television', 2020, 8.3, 'Asia Kate Dillon', 'Narrator (voice)'),
#  ('Visible: Out On Television', 2020, 8.3, 'Neil Patrick Harris', 'Narrator (voice)'),
#  ('Visible: Out On Television', 2020, 8.3, 'Lena Waithe', 'Narrator (voice)'),
#  ('Visible: Out On Television', 2020, 8.3, 'Wanda Sykes', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Billy Porter', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Joey Soloway', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Laverne Cox', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Michaela Jaé Rodriguez', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Oprah Winfrey', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Ellen DeGeneres', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Wilson Cruz', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Abbi Jacobson', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Anderson Cooper', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Jonathan Groff', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Caitlyn Jenner', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Ilana Glazer', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Rufus Wainwright', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Rachel Maddow', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Adam Lambert', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Andy Cohen', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Tim Gunn', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Candis Cayne', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Don Lemon', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Jesse Tyler Ferguson', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Ryan Phillippe', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'George Takei', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Michael Douglas', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Lena Dunham', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Norman Lear', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Miss Major Griffin-Gracy', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Dustin Lance Black', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Robert Benevides', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Bob LaHendro', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Armistead Maupin', 'Self'),
#  ('Visible: Out On Television', 2020, 8.3, 'Richard Socarides', 'Self'),
#  ('Losing Alice', 2020, 6.6, 'Ayelet Zurer', 'Alice'),
#  ('Losing Alice', 2020, 6.6, 'Lihi Kornowski', 'Sophie'),
#  ('Losing Alice', 2020, 6.6, 'Gal Toren', 'David'),
#  ('Losing Alice', 2020, 6.6, 'Yossi Marshek', 'Tamir'),
#  ('Losing Alice', 2020, 6.6, 'Shai Avivi', 'Ami'),
#  ('Losing Alice', 2020, 6.6, 'Iris Bahr', 'Rita'),
#  ('Losing Alice', 2020, 6.6, 'Sigal Avin', None),
#  ('The Oprah Conversation', 2020, 3.2, 'Oprah Winfrey', 'Self - Host'),
#  ('Fraggle Rock: Rock On!', 2020, 6.3, 'Karen Prell', 'Red Fraggle'),
#  ('Fraggle Rock: Rock On!', 2020, 6.3, 'John Tartaglia', 'Gobo Fraggle'),
#  ('Fraggle Rock: Rock On!', 2020, 6.3, 'Donna Kimball', 'Mokey Fraggle'),
#  ('Fraggle Rock: Rock On!', 2020, 6.3, 'Dave Goelz', 'Boober Fraggle / Travelling Matt (voice)'),
#  ('Fraggle Rock: Rock On!', 2020, 6.3, 'Frankie Cordero', 'Wembley Fraggle (voice)'),
#  ('Hala', 2019, 6.2, 'Geraldine Viswanathan', 'Hala Masood'),
#  ('Hala', 2019, 6.2, 'Jack Kilmer', 'Jesse Ross'),
#  ('Hala', 2019, 6.2, 'Gabriel Luna', 'Mr. Lawrence'),
#  ('Hala', 2019, 6.2, 'Purbi Joshi', 'Eram Masood'),
#  ('Hala', 2019, 6.2, 'Hatta Azad Khan', 'Zahid'),
#  ('Hala', 2019, 6.2, 'Anna Chlumsky', 'Shannon Taylor'),
#  ('Hala', 2019, 6.2, 'Jimmy Chunga', 'Photographer'),
#  ('Hala', 2019, 6.2, 'Taylor Marie Blim', 'Melanie'),
#  ('Hala', 2019, 6.2, 'Charin Alvarez', 'Principal'),
#  ('Hala', 2019, 6.2, 'Minhal Baig', None),
#  ('Earth at Night in Color', 2020, 8.2, 'Tom Hiddleston', 'Narrator (voice)'),
#  ('Stillwater', 2020, 8.3, 'James Sie', 'Stillwater (voice)'),
#  ('Stillwater', 2020, 8.3, 'Eva Binder', 'Addy (voice)'),
#  ('Stillwater', 2020, 8.3, 'Tucker Chandler', 'Michael (voice)'),
#  ('Stillwater', 2020, 8.3, 'Judah Mackey', 'Karl (voice)'),
#  ('Little Voice', 2020, 7.2, "Brittany O'Grady", 'Bess King'),
#  ('Little Voice', 2020, 7.2, 'Kevin Valdez', 'Louie'),
#  ('Little Voice', 2020, 7.2, 'Shalini Bathina', 'Prisha'),
#  ('Little Voice', 2020, 7.2, 'Sean Teale', 'Ethan'),
#  ('Little Voice', 2020, 7.2, 'Colton Ryan', 'Samuel'),
#  ('Little Voice', 2020, 7.2, 'Phillip Johnson Richardson', 'Benny'),
#  ('Snoopy in Space', 2019, 7.6, 'Hattie Kragten', 'Sally (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Terry McGurrin', 'Snoopy (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Rob Tinkler', 'Woodstock (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Seán Cullen', 'Bird Bud 1 (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Julie Lemieux', 'Bird Bud 2 (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Nicole Byer', 'C.A.R.A. (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Tyler James Nathan', 'Charlie Brown (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Christian Dal Dosso', 'Franklin (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Holly Gorski', 'Marcie (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Isabella Leo', 'Lucy (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Isis Moore', 'Peppermint Patty (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'Wyatt White', 'Linus (voice)'),
#  ('Snoopy in Space', 2019, 7.6, 'David Berni', 'Bird Bud 3 (voice)'),
#  ('The Elephant Queen', 2019, 7.8, 'Chiwetel Ejiofor', 'Narrator'),
#  ('The Elephant Queen', 2019, 7.8, 'Mark Deeble', None),
#  ('The Elephant Queen', 2019, 7.8, 'Victoria Stone', None),
#  ("Bruce Springsteen's Letter to You", 2020, 7.3, 'Bruce Springsteen', 'Self'),
#  ("Bruce Springsteen's Letter to You", 2020, 7.3, 'Roy Bittan', 'Self'),
# ...
#  ('Severance', 2022, 8.7, 'Christopher Walken', 'Burt Goodman'),
#  ('Severance', 2022, 8.7, 'Patricia Arquette', 'Harmony Cobel'),
#  ('Slow Horses', 2022, 7.9, 'Gary Oldman', 'Jackson Lamb'),
#  ('Slow Horses', 2022, 7.9, 'Jack Lowden', 'River Cartwright'),
#  ('Slow Horses', 2022, 7.9, 'Kristin Scott Thomas', 'Diana Taverner'),
#  ('Black Bird', 2022, 8.1, 'Taron Egerton', "James 'Jimmy' Keene"),
#  ('Black Bird', 2022, 8.1, 'Paul Walter Hauser', 'Larry Hall'),
#  ('Black Bird', 2022, 8.1, 'Ray Liotta', "James 'Big Jim' Keene"),
#  ('Black Bird', 2022, 8.1, 'Greg Kinnear', 'Brian Miller'),
#  ('Black Bird', 2022, 8.1, 'Sepideh Moafi', 'Lauren McCauley'),
#  ('Black Bird', 2022, 8.1, 'Laney Stiebing', None),
#  ('Black Bird', 2022, 8.1, 'Robert Wisdom', 'Edmund Beaumont'),
#  ('Bad Sisters', 2022, 8.3, 'Sharon Horgan', 'Eva Garvey'),
#  ('Bad Sisters', 2022, 8.3, 'Anne-Marie Duff', 'Grace Williams'),
#  ('Bad Sisters', 2022, 8.3, 'Eva Birthistle', 'Ursula Flynn'),
#  ('Bad Sisters', 2022, 8.3, 'Sarah Greene', 'Bibi Garvey'),
#  ('Bad Sisters', 2022, 8.3, 'Eve Hewson', 'Becka Garvey'),
#  ('Bad Sisters', 2022, 8.3, 'Claes Bang', 'John Paul Williams'),
#  ('Bad Sisters', 2022, 8.3, 'Brian Gleeson', 'Thomas Claffin'),
#  ('Bad Sisters', 2022, 8.3, 'Daryl McCormack', 'Matt Claffin'),
#  ('Bad Sisters', 2022, 8.3, 'Saise Ní Chuinn', 'Blanaid Williams'),
#  ('Bad Sisters', 2022, 8.3, 'Rebecca Gatward', None),
#  ('Bad Sisters', 2022, 8.3, 'Dearbhla Walsh', None),
#  ('Bad Sisters', 2022, 8.3, 'Josephine Bornebusch', None),
#  ('Causeway', 2022, 6.6, 'Jennifer Lawrence', 'Lynsey'),
#  ('Causeway', 2022, 6.6, 'Brian Tyree Henry', 'James'),
#  ('Causeway', 2022, 6.6, 'Linda Emond', 'Gloria'),
#  ('Causeway', 2022, 6.6, 'Jayne Houdyshell', 'Sharon'),
#  ('Causeway', 2022, 6.6, 'Stephen McKinley Henderson', 'Dr. Lucas'),
#  ('Causeway', 2022, 6.6, 'Russell Harvard', 'Justin'),
#  ('Causeway', 2022, 6.6, 'Sean Carvajal', 'Santiago'),
#  ('Causeway', 2022, 6.6, 'Frederick Weller', 'Rick'),
#  ('Causeway', 2022, 6.6, 'Will Pullen', 'Bro'),
#  ('Causeway', 2022, 6.6, 'Neal Huff', 'Neuropsychologist'),
#  ('Causeway', 2022, 6.6, 'Danny Wolohan', 'Jim'),
#  ('Causeway', 2022, 6.6, 'Han Soto', 'Physiotherapist'),
#  ('Causeway', 2022, 6.6, 'Natalie Pilie', 'Physiotherapist'),
#  ('Causeway', 2022, 6.6, 'Suzette Stuebben', 'Bartender'),
#  ('Causeway', 2022, 6.6, 'Lila Neugebauer', None),
#  ('Foundation', 2021, 7.4, 'Jared Harris', 'Hari Seldon'),
#  ('Foundation', 2021, 7.4, 'Lou Llobell', 'Gaal Dornick'),
#  ('Foundation', 2021, 7.4, 'Lee Pace', 'Brother Day'),
#  ('Foundation', 2021, 7.4, 'Leah Harvey', 'Salvor Hardin'),
#  ('Foundation', 2021, 7.4, 'Laura Birn', 'Demerzel'),
#  ('Foundation', 2021, 7.4, 'Terrence Mann', 'Brother Dusk'),
#  ('Foundation', 2021, 7.4, 'Cassian Bilton', 'Brother Dawn'),
#  ('Echo 3', 2022, 6.5, 'Luke Evans', "Alex 'Bambi' Chesborough"),
#  ('Echo 3', 2022, 6.5, 'Michiel Huisman', "Eric 'Prince' Haas"),
#  ('Echo 3', 2022, 6.5, 'Jessica Collins', 'Amber Chesborough'),
#  ('Echo 3', 2022, 6.5, 'James Udom', 'Mitch'),
#  ('Echo 3', 2022, 6.5, 'Elizabeth Anweis', 'Natalie Foster'),
#  ('Echo 3', 2022, 6.5, 'Martina Gusman', 'Violetta Cadiz'),
#  ('CODA', 2021, 8.0, 'Emilia Jones', 'Ruby Rossi'),
#  ('CODA', 2021, 8.0, 'Marlee Matlin', 'Jackie Rossi'),
#  ('CODA', 2021, 8.0, 'Troy Kotsur', 'Frank Rossi'),
#  ('CODA', 2021, 8.0, 'Eugenio Derbez', 'Bernardo Villalobos'),
#  ('CODA', 2021, 8.0, 'Ferdia Walsh-Peelo', 'Miles'),
#  ('CODA', 2021, 8.0, 'Daniel Durant', 'Leo Rossi'),
#  ('CODA', 2021, 8.0, 'Amy Forsyth', 'Gertie'),
#  ('CODA', 2021, 8.0, 'Kevin Chapman', 'Brady'),
#  ('CODA', 2021, 8.0, 'John Fiore', 'Tony Salgado'),
#  ('CODA', 2021, 8.0, 'Lonnie Farmer', 'Arthur'),
#  ('CODA', 2021, 8.0, 'Courtland Jones', 'Ms. Simon'),
#  ('CODA', 2021, 8.0, 'Molly Beth Thomas', 'Audra'),
#  ('CODA', 2021, 8.0, 'Ayana Brown', 'Guidance Counselor'),
#  ('CODA', 2021, 8.0, 'Jason Pugatch', 'Doctor'),
#  ('CODA', 2021, 8.0, 'Kyana Fanene', 'Riff Girl'),
#  ('CODA', 2021, 8.0, 'Anilee List', 'Adele Girl'),
#  ('CODA', 2021, 8.0, 'Stone Martin', 'Harry Potter Boy'),
#  ('CODA', 2021, 8.0, 'Maeve Chapman', 'Shaker Girl'),
#  ('CODA', 2021, 8.0, 'Stephen Caliskan', 'Tall Boy'),
#  ('CODA', 2021, 8.0, 'Amanda Bradshaw', 'Shy Girl'),
#  ('CODA', 2021, 8.0, 'Bryan Sabbag', 'Broadway Boy'),
#  ('CODA', 2021, 8.0, 'Kayla Caulfield', 'Off Key Girl'),
#  ('CODA', 2021, 8.0, 'Samidio DePina', 'Suave Boy'),
#  ('CODA', 2021, 8.0, 'Dominic Andersen', 'Bass Boy'),
#  ('CODA', 2021, 8.0, 'Jose Guns Alves', 'Mondo'),
#  ('CODA', 2021, 8.0, 'Owen Burke', 'Jimmy'),
#  ('CODA', 2021, 8.0, 'Mark Pettograsso', 'Bar Bully'),
#  ('CODA', 2021, 8.0, 'Tony Viveiros', 'Bartender'),
#  ('CODA', 2021, 8.0, 'Armen Garo', 'Gio Salgado'),
#  ('CODA', 2021, 8.0, 'Jared Voss', 'John Kaufman'),
#  ('CODA', 2021, 8.0, 'Emilia Faucher', 'Misha'),
#  ('CODA', 2021, 8.0, 'Marilyn Busch', 'Nina'),
#  ('CODA', 2021, 8.0, 'Melissa McMeekin', 'Barb'),
#  ('CODA', 2021, 8.0, 'Erica McDermott', 'Angela'),
#  ('CODA', 2021, 8.0, 'Garrett McKechnie', 'Chet Turner'),
#  ('CODA', 2021, 8.0, 'Rebecca Gibel', 'Joanne Biles'),
#  ('CODA', 2021, 8.0, 'TJ Ciarametaro', 'Coast Guard Boarding Officer'),
#  ('CODA', 2021, 8.0, 'Gary Galone', 'Coast Guard Officer'),
#  ('CODA', 2021, 8.0, 'Nikki Kim', 'Monitor #1'),
#  ('CODA', 2021, 8.0, 'Mary Ann Schaub', 'Monitor #2'),
#  ('CODA', 2021, 8.0, 'Cassandra Berta', 'Vocalist'),
#  ('CODA', 2021, 8.0, 'Sarah Clarke', 'Tanya'),
#  ('CODA', 2021, 8.0, 'Rena Maliszewski', 'Female Jury Member'),
#  ('CODA', 2021, 8.0, 'David Newsom', 'Male Jury Member'),
#  ('CODA', 2021, 8.0, 'Kiara Pichardo', 'Cashier (uncredited)'),
#  ('CODA', 2021, 8.0, 'Pamela Jayne Morgan', 'Shopper Woman (uncredited)'),
#  ('CODA', 2021, 8.0, 'Elbert Kim', "Jackie Rossi's Attorney (uncredited)"),
#  ('CODA', 2021, 8.0, 'Dominic Cannarella-Andersen', 'Bass Boy'),
#  ('CODA', 2021, 8.0, 'Siân Heder', None),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Jude Coward Nicoll', 'The Boy (voice)'),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Tom Hollander', 'The Mole (voice)'),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Idris Elba', 'The Fox (voice)'),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Gabriel Byrne', 'The Horse (voice)'),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Peter Baynton', None),
#  ('The Boy, the Mole, the Fox and the Horse', 2022, 7.9, 'Charlie Mackesy', None),
#  ('Pachinko', 2022, 8.4, 'Youn Yuh-jung', 'Older Sunja'),
#  ('Pachinko', 2022, 8.4, 'Kim Min-ha', 'Teen Sunja'),
#  ('Pachinko', 2022, 8.4, 'Lee Min-ho\xa0', 'Hansu'),
#  ('Pachinko', 2022, 8.4, 'Jin Ha', 'Solomon'),
#  ('Pachinko', 2022, 8.4, 'Soji Arai', 'Mozasu'),
#  ('Pachinko', 2022, 8.4, 'Jeong In-ji', 'Yangjin'),
#  ('Pachinko', 2022, 8.4, 'Noh Sang-hyun', 'Isak'),
#  ('Pachinko', 2022, 8.4, 'Jung Eun-chae', 'Young Kyunghee'),
#  ('Pachinko', 2022, 8.4, 'Kaho Minami', 'Etsuko'),
#  ('Pachinko', 2022, 8.4, 'Anna Sawai', 'Naomi'),
#  ('Pachinko', 2022, 8.4, 'Jimmi Simpson', 'Tom Andrews'),
#  ('Pachinko', 2022, 8.4, 'Han Jun-woo', 'Yoseb'),
#  ('The Mosquito Coast', 2021, 6.8, 'Justin Theroux', 'Allie Fox'),
#  ('The Mosquito Coast', 2021, 6.8, 'Melissa George', 'Margot Fox'),
#  ('The Mosquito Coast', 2021, 6.8, 'Logan Polish', 'Dina Fox'),
#  ('The Mosquito Coast', 2021, 6.8, 'Gabriel Bateman', 'Charlie Fox'),
#  ('The Mosquito Coast', 2021, 6.8, 'Natalia Cordova-Buckley', 'Isela'),
#  ('The Mosquito Coast', 2021, 6.8, 'Daniel Raymont', 'Guillermo Bautista'),
#  ('The Mosquito Coast', 2021, 6.8, 'Ian Hart', 'Bill Lee'),
#  ('The Mosquito Coast', 2021, 6.8, 'Ariyon Bakare', 'Richard Beaumont'),
#  ('Shantaram', 2022, 7.5, 'Charlie Hunnam', 'Dale Conti/Lin Ford'),
#  ('Shantaram', 2022, 7.5, 'Shubham Saraf', "Prabaker 'Prabhu' Kharre"),
#  ('Shantaram', 2022, 7.5, 'Antonia Desplat', 'Karla Saaranen'),
#  ('Shantaram', 2022, 7.5, 'Elektra Jansson-Kilbey', 'Lisa Carter'),
#  ('Shantaram', 2022, 7.5, 'Fayssal Bazzi', 'Abdullah Taheri'),
#  ('Shantaram', 2022, 7.5, 'Elham Ehsas', 'Sebastian Modena'),
#  ('Shantaram', 2022, 7.5, 'Sujaya Dasgupta', 'Kavita Singh'),
#  ('Shantaram', 2022, 7.5, 'Rachel Kamath', 'Parvati'),
#  ('Shantaram', 2022, 7.5, 'Alexander Siddig', 'Khader Khan'),
#  ('WeCrashed', 2022, 7.3, 'Jared Leto', 'Adam Neumann'),
#  ('WeCrashed', 2022, 7.3, 'Anne Hathaway', 'Rebekah Neumann'),
#  ('WeCrashed', 2022, 7.3, 'Kyle Marvin', 'Miguel McKelvey'),
#  ('Loot', 2022, 6.7, 'Maya Rudolph', 'Molly Wells / Molly Novak'),
#  ('Loot', 2022, 6.7, 'Michaela Jaé Rodriguez', 'Sofia Salinas'),
#  ('Loot', 2022, 6.7, 'Nat Faxon', 'Arthur'),
#  ('Loot', 2022, 6.7, 'Joel Kim Booster', 'Nicholas'),
#  ('Loot', 2022, 6.7, 'Ron Funches', 'Howard'),
#  ('Loot', 2022, 6.7, 'Meagen Fay', 'Rhonda'),
#  ('Loot', 2022, 6.7, 'Stephanie Styles', 'Ainsley'),
#  ('Loot', 2022, 6.7, 'Miguel Arteta', None),
#  ('The Problem With Jon Stewart', 2021, 7.1, 'Jon Stewart', 'Self - Host'),
#  ('The Afterparty', 2022, 7.2, 'Tiffany Haddish', 'Detective Danner'),
#  ('The Afterparty', 2022, 7.2, 'Sam Richardson', 'Aniq'),
#  ('The Afterparty', 2022, 7.2, 'Zoë Chao', 'Zoe'),
#  ('The Afterparty', 2022, 7.2, 'Ben Schwartz', 'Yasper'),
#  ('The Afterparty', 2022, 7.2, 'Ike Barinholtz', 'Brett'),
#  ('The Afterparty', 2022, 7.2, 'Ilana Glazer', 'Chelsea'),
#  ('The Afterparty', 2022, 7.2, 'Dave Franco', 'Xavier'),
#  ('The Afterparty', 2022, 7.2, 'Jamie Demetriou', 'Walt'),
#  ('The Afterparty', 2022, 7.2, 'John Early', 'Detective Culp'),
#  ('The Afterparty', 2022, 7.2, 'Genevieve Angelson', 'Indigo'),
#  ('Schmigadoon!', 2021, 7.3, 'Keegan-Michael Key', 'Josh Skinner'),
#  ('Schmigadoon!', 2021, 7.3, 'Cecily Strong', 'Melissa Gimble'),
#  ('Schmigadoon!', 2021, 7.3, 'Fred Armisen', 'Reverend Howard Layton'),
#  ('Schmigadoon!', 2021, 7.3, 'Dove Cameron', 'Betsy McDonough'),
#  ('Schmigadoon!', 2021, 7.3, 'Jaime Camil', 'Doc Jorge Lopez'),
#  ('Schmigadoon!', 2021, 7.3, 'Kristin Chenoweth', 'Mildred Layton'),
#  ('Schmigadoon!', 2021, 7.3, 'Alan Cumming', 'Mayor Aloysius Menlove'),
#  ('Schmigadoon!', 2021, 7.3, 'Ariana DeBose', 'Emma Tate'),
#  ('Schmigadoon!', 2021, 7.3, 'Ann Harada', 'Florence Menlove'),
#  ('Schmigadoon!', 2021, 7.3, 'Jane Krakowski', 'The Countess'),
#  ('Schmigadoon!', 2021, 7.3, 'Aaron Tveit', 'Danny Bailey'),
#  ('Acapulco', 2021, 7.7, 'Eugenio Derbez', 'Máximo Gallardo'),
#  ('Acapulco', 2021, 7.7, 'Enrique Arrizon', 'Máximo Gallardo (Young)'),
#  ('Acapulco', 2021, 7.7, 'Raphael Alejandro', 'Hugo'),
#  ('Acapulco', 2021, 7.7, 'Camila Perez', 'Julia'),
#  ('Acapulco', 2021, 7.7, 'Chord Overstreet', 'Chad'),
#  ('Acapulco', 2021, 7.7, 'Fernando Carsa', 'Memo'),
#  ('Acapulco', 2021, 7.7, 'Jessica Collins', 'Diane'),
#  ('Acapulco', 2021, 7.7, 'Vanessa Bauche', 'Nora'),
#  ('Acapulco', 2021, 7.7, 'Regina Reynoso', 'Sara'),
#  ('Acapulco', 2021, 7.7, 'Rafael Cebrian', 'Hector'),
#  ('Acapulco', 2021, 7.7, 'Bianca Marroquín', 'Older Sara'),
#  ('Acapulco', 2021, 7.7, 'Regina Orozco', 'Lupe'),
#  ('Acapulco', 2021, 7.7, 'Gabriela Milla', 'Isabel'),
#  ('Five Days at Memorial', 2022, 7.7, 'Vera Farmiga', 'Dr. Anna Pou'),
#  ('Five Days at Memorial', 2022, 7.7, 'Cherry Jones', 'Susan Mulderick'),
#  ('Five Days at Memorial', 2022, 7.7, 'Cornelius Smith, Jr.', 'Dr. Bryant King'),
#  ('Five Days at Memorial', 2022, 7.7, 'Robert Pine', 'Dr. Horace Baltz'),
#  ('Five Days at Memorial', 2022, 7.7, 'Adepero Oduye', 'Karen Wynn'),
#  ('Five Days at Memorial', 2022, 7.7, 'Julie Ann Emery', 'Diane Robichaux'),
#  ('Five Days at Memorial', 2022, 7.7, 'Michael Gaston', "Arthur 'Butch' Schafer"),
#  ('Five Days at Memorial', 2022, 7.7, 'Molly Hager', 'Virginia Rider'),
#  ('Five Days at Memorial', 2022, 7.7, 'Carlton Cuse', None),
#  ('Five Days at Memorial', 2022, 7.7, 'John Ridley', None),
#  ('Five Days at Memorial', 2022, 7.7, 'Wendey Stanzler', None),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Zac Efron', "John 'Chickie' Donohue"),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Russell Crowe', 'Arthur Coates'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Kyle Allen', 'Bobby Pappas'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Bill Murray', 'The Colonel'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Jake Picking', 'Rick Duggan'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Will Ropp', 'Kevin McLoone'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Archie Renaux', 'Tom Collins'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Ruby Ashbourne Serkis', 'Christine'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Will Hochman', 'Tommy Minogue'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Christopher Reed Brown', 'Noodle'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Joe Adler', 'Red'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'MacGregor Arney', 'Brendan'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Hal Cumpston', 'Leary'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Kristin Carey', 'Mrs. Minogue'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Paul Adelstein', 'Mr. Donohue'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Matt Cook', 'Lt. Habershaw'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Shirleyann Kaladjian', 'Mrs. Donohue'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Kevin Tran', "Hieu 'Oklahoma'"),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Bob Farrelly', 'Baby-Face'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Branden Lindsay', 'Jimmy Burns'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Omari K. Chancellor', 'Erickson'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Carlos Arroyo', 'Sgt. Major Perez'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Kelvin Delgado', 'Gines'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Thomas Jordan', 'Leasco'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Phil Anthony Edwards', 'Duvall'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Thai-Hoa Le', 'Bartender Hien'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Deanna Russo', 'Correspondent Woelfel'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'James Laver', 'Correspondent Lewis'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Paul Sloan', 'CIA Agent'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Nguyen Viet Anh', 'ARVN Interpreter'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Alex Huynh', 'Prisoner'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Kevin J. Flynn', 'Seafarers Union Clerk'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Sean Gildea', 'Drake Captain Beauchene'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Goya Robles', 'Almeida'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Bradley M. Hayes', 'Saigon MP'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Brian Jarvis', 'Major Breuer'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Tim Hoffmann', 'Private Nolan'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Mike Hatton', 'Captain Dyer'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Mike Gray', 'Lt. Fusco'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Thomas Ronca', 'Cpl. Warner'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Steve Sweeney', 'Lt. Commander Washburn'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Josefina Grajo Villanueva', 'Embassy Bureaucrat'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Jackie Flynn', 'Major Flynn'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'James Fahselt', 'Mason'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Anabel Graetz', 'Nanny'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Ngo Hoang Long', 'Caravelle Porter'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Lisa Rothschiller', 'Mrs. Collins'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'John Garrett Mahlmeister', 'LZ Jane Radio Operator'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Michael Grant Selby', 'Jeep Soldier Soucy'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Terry Mullany', 'Jeep Soldier Hardcastle'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Alex Winters', 'Long Binh Private'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Malik Tyshawn Louis', 'Long Binh Fireman'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Mata Toure', 'Medic Molloy'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Finn Gesner', 'Cool Breeze'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Apple Farrelly', 'Protester #1'),
#  ('The Greatest Beer Run Ever', 2022, 6.8, 'Rory Gesner', 'Protester #2'),
#  ...]

# %%
session.query(titles.title , titles.release_year , titles.imdb_score , credits.name , credits.character , titles.age_certification , titles.description)\
       .filter(titles.id == credits.title_id).first()
# Out:
# ('A Charlie Brown Christmas', 1965, 8.3, 'Peter Robbins', 'Charlie Brown (voice)', 'G', "When Charlie Brown complains about the overwhelming materialism that he sees amongst everyone during the Christmas season, Lucy suggests that he beco ... (98 characters truncated) ...  When an attempt to restore the proper spirit with a forlorn little fir Christmas tree fails, he needs Linus' help to learn the meaning of Christmas.")

# %%
session.close()
